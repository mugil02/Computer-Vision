# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/archive (5)/test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    pad_to_aspect_ratio=False,
    data_format=None,
    verbose=True,
)
# Out:
# Found 359 files belonging to 36 classes.

# %% [markdown]
# ##loading model

# %%
cnn = tf.keras.models.load_model('/content/trained_model (4).h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %% [markdown]
# ##performing prediction on single image

# %%
import cv2
image_path = '/content/drive/MyDrive/archive (5)/test/potato/Image_7.jpg'
img =cv2.imread(image_path)
plt.imshow(img)
plt.title("Test image")
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ##Testing Model

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])#converting single image to batch
predictions = cnn.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step

# %%
print(predictions[0])
print(max(predictions[0]))
# Out:
# [5.9877253e-10 1.8592712e-06 3.3635820e-12 1.6813435e-13 4.8927571e-17
#  1.7546858e-08 4.1719605e-16 3.2063566e-13 3.3486252e-14 3.7142536e-11
#  5.6088701e-16 5.3338813e-16 6.3902932e-11 1.4488788e-12 2.8859683e-14
#  4.5880734e-15 1.4015071e-13 1.0105211e-10 1.6555654e-15 7.0090078e-07
#  1.2905549e-06 3.0480515e-10 7.6921129e-11 3.6299522e-10 1.9652875e-18
#  6.2111510e-17 3.4561514e-12 9.9999607e-01 2.0003184e-14 9.4991289e-14
#  3.2699059e-22 5.7663402e-10 6.6975359e-10 1.6079696e-14 3.6768176e-15
#  2.7736483e-13]
# 0.99999607

# %%
test_set.class_names
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
result_index = np.where(predictions[0] == max(predictions[0]))
print(result_index[0][0])
# Out:
# 27

# %%
plt.imshow(img)
plt.title("Test image")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
print("It's a {}".format(test_set.class_names[result_index[0][0]]))
# Out:
# It's a potato
